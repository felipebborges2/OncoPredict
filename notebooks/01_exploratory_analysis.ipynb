# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import load_breast_cancer

# %%
data = load_breast_cancer()

df = pd.DataFrame(data.data, columns=data.feature_names)
df["target"] = data.target

df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
data.target_names
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %%
df["target"].value_counts()
# Out:
# target
# 1    357
# 0    212
# Name: count, dtype: int64

# %%
df["target"] = df["target"].map({0: "malignant", 1: "benign"})
df["target"].value_counts()
# Out:
# target
# benign       357
# malignant    212
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df.isnull().sum().sort_values(ascending=False).head(10)
# Out:
# mean radius                0
# concavity error            0
# worst fractal dimension    0
# worst symmetry             0
# worst concave points       0
# worst concavity            0
# worst compactness          0
# worst smoothness           0
# worst area                 0
# worst perimeter            0
# dtype: int64

# %%
df["target"].value_counts().plot(kind="bar")
plt.title("Distribuição das classes")
plt.xlabel("Classe")
plt.ylabel("Quantidade")
plt.show()

# %%
corr = df.drop(columns="target").corr()

plt.figure(figsize=(14, 10))
plt.imshow(corr, aspect="auto")
plt.colorbar()
plt.title("Matriz de Correlação das Features")
plt.show()

# %%
selected_features = [
    "mean radius",
    "mean texture",
    "mean perimeter",
    "mean area",
    "mean smoothness"
]

df[selected_features].hist(figsize=(14, 8), bins=20)
plt.suptitle("Distribuição de features selecionadas", y=1.02)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

feature = "mean radius"

classes = ["benign", "malignant"]
data_to_plot = [df[df["target"] == c][feature] for c in classes]

plt.figure(figsize=(8, 5))
plt.boxplot(data_to_plot, tick_labels=classes)
plt.title(f"Distribuição de {feature} por classe")
plt.xlabel("Classe")
plt.ylabel(feature)
plt.show()

# %%
target_numeric = load_breast_cancer().target
df_numeric = pd.DataFrame(load_breast_cancer().data, columns=load_breast_cancer().feature_names)
df_numeric["target"] = target_numeric

correlations = df_numeric.corr(numeric_only=True)["target"].drop("target").sort_values()

print("Features mais negativamente correlacionadas com target:")
print(correlations.head(10))
print()
print("Features mais positivamente correlacionadas com target:")
print(correlations.tail(10))
# Out:
# Features mais negativamente correlacionadas com target:
# worst concave points   -0.793566
# worst perimeter        -0.782914
# mean concave points    -0.776614
# worst radius           -0.776454
# mean perimeter         -0.742636
# worst area             -0.733825
# mean radius            -0.730029
# mean area              -0.708984
# mean concavity         -0.696360
# worst concavity        -0.659610
# Name: target, dtype: float64
#
# Features mais positivamente correlacionadas com target:
# mean smoothness           -0.358560
# mean symmetry             -0.330499
# worst fractal dimension   -0.323872
# compactness error         -0.292999
# concavity error           -0.253730
# fractal dimension error   -0.077972
# symmetry error             0.006522
# texture error              0.008303
# mean fractal dimension     0.012838
# smoothness error           0.067016
# Name: target, dtype: float64

# %%
df["target"].value_counts().plot(kind="bar")
plt.title("Distribuição das classes")
plt.xlabel("Classe")
plt.ylabel("Quantidade")
plt.tight_layout()
plt.savefig("../figures/class_distribution.png", dpi=300)
plt.show()

# %%
df[selected_features].hist(figsize=(14, 8), bins=20)
plt.suptitle("Distribuição de features selecionadas", y=1.02)
plt.tight_layout()
plt.savefig("../figures/feature_histograms.png", dpi=300)
plt.show()

# %% [markdown]
# ## Separabilidade entre classes
#
# Uma das perguntas mais importantes na análise exploratória é: **as duas classes são visualmente separáveis?**
#
# Se sim, isso justifica o uso de modelos lineares simples (como Regressão Logística) — não precisamos de algoritmos muito complexos.
#
# Vamos plotar as duas features com maior correlação com o diagnóstico: `worst concave points` e `worst perimeter`.

# %%
colors = {"malignant": "#e74c3c", "benign": "#2ecc71"}

plt.figure(figsize=(9, 6))
for label, group in df.groupby("target"):
    plt.scatter(
        group["worst concave points"],
        group["worst perimeter"],
        label=label,
        color=colors[label],
        alpha=0.6,
        edgecolors="white",
        linewidth=0.4,
        s=60
    )

plt.xlabel("Worst Concave Points")
plt.ylabel("Worst Perimeter")
plt.title("Separabilidade das classes — features mais correlacionadas com o diagnóstico")
plt.legend(title="Diagnóstico")
plt.tight_layout()
plt.savefig("../figures/class_separability.png", dpi=150)
plt.show()

# %% [markdown]
# ## Boxplots das features mais relevantes por classe
#
# O **boxplot** é um gráfico que mostra a distribuição de valores de uma variável. Ele exibe:
# - A linha do meio: **mediana** (valor central)
# - A caixa: onde estão os 50% centrais dos dados
# - Os "bigodes": o intervalo geral dos dados
# - Os pontos fora: **outliers** (valores atípicos)
#
# Abaixo, comparamos as 6 features com maior correlação com o diagnóstico entre as duas classes.

# %%
top_features = [
    "worst concave points",
    "worst perimeter",
    "mean concave points",
    "worst radius",
    "mean perimeter",
    "worst area"
]

fig, axes = plt.subplots(2, 3, figsize=(14, 8))
axes = axes.flatten()

classes = ["benign", "malignant"]
colors = ["#2ecc71", "#e74c3c"]

for i, feature in enumerate(top_features):
    data_to_plot = [df[df["target"] == c][feature] for c in classes]
    bp = axes[i].boxplot(
        data_to_plot,
        tick_labels=classes,
        patch_artist=True,
        medianprops=dict(color="black", linewidth=2)
    )
    for patch, color in zip(bp["boxes"], colors):
        patch.set_facecolor(color)
        patch.set_alpha(0.7)
    axes[i].set_title(feature, fontsize=10)
    axes[i].set_ylabel("Valor")

plt.suptitle("Distribuição das features mais relevantes por classe", fontsize=13, y=1.02)
plt.tight_layout()
plt.savefig("../figures/top_features_boxplots.png", dpi=150)
plt.show()

# %% [markdown]
# ## Heatmap de correlação entre as features mais relevantes
#
# O heatmap original mostrava todas as 30 features — ficava grande demais para ler. Aqui filtramos apenas as **10 features mais correlacionadas com o diagnóstico** e exibimos os valores numericamente, tornando muito mais fácil identificar quais features caminham juntas.
#
# **Por que isso importa?** Features muito correlacionadas entre si carregam informação redundante. Saber disso ajuda a entender o comportamento dos modelos e, no futuro, a simplificar o dataset.

# %%
import seaborn as sns

df_numeric = df.drop(columns="target")
target_corr = df_numeric.corrwith(pd.Series(load_breast_cancer().target, name="target"))
top_10_features = target_corr.abs().sort_values(ascending=False).head(10).index.tolist()

corr_matrix = df_numeric[top_10_features].corr()

plt.figure(figsize=(11, 8))
sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    center=0,
    linewidths=0.5,
    square=True,
    cbar_kws={"shrink": 0.8}
)
plt.title("Correlação entre as 10 features mais relevantes para o diagnóstico", pad=15)
plt.tight_layout()
plt.savefig("../figures/correlation_heatmap_top10.png", dpi=150)
plt.show()
